# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import matplotlib.dates as mdates

# %%
stocks_file_path = 'sp500_index.csv'
stocks_df = pd.read_csv(stocks_file_path)

# %%
fed_rates_file_path = 'federal-reserve-rates.csv'
fed_df = pd.read_csv(fed_rates_file_path)

# %%
party_control_file_path = 'MinWage_PartyControl.csv'
pc_df = pd.read_csv(party_control_file_path)

# %%
stocks_df.head(-10)
# Out:
#             Date   S&P500
# 0     2013-10-28  1762.11
# 1     2013-10-29  1771.95
# 2     2013-10-30  1763.31
# 3     2013-10-31  1756.54
# 4     2013-11-01  1761.64
# ...          ...      ...
# 2501  2023-10-05  4258.19
# 2502  2023-10-06  4308.50
# 2503  2023-10-09  4335.66
# 2504  2023-10-10  4358.24
# 2505  2023-10-11  4376.95
#
# [2506 rows x 2 columns]

# %%
stocks_df['Date'] = pd.to_datetime(stocks_df['Date'])

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(stocks_df['Date'], stocks_df['S&P500'], marker='o', markersize=3, linestyle='-', color='b')
plt.title('S&P 500 Over Time')
plt.xlabel('Date')
plt.ylabel('S&P 500')
plt.grid(True)

# Customize the x-axis with date numbers
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=182))

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
pc_df.head(-10)
# Out:
#     Year   PresParty  SenParty  HouseParty TrifectaFlag FedMinWage RateChange  \
# 0   1938    Democrat  Democrat    Democrat     Democrat      $0.25      $0.25
# 1   1939    Democrat  Democrat    Democrat     Democrat      $0.30      $0.05
# 2   1940    Democrat  Democrat    Democrat     Democrat      $0.30      $0.00
# 3   1941    Democrat  Democrat    Democrat     Democrat      $0.30      $0.00
# 4   1942    Democrat  Democrat    Democrat     Democrat      $0.30      $0.00
# ..   ...         ...       ...         ...          ...        ...        ...
# 69  2007  Republican  Democrat    Democrat         None      $5.85      $0.70
# 70  2008  Republican  Democrat    Democrat         None      $6.55      $0.70
# 71  2009    Democrat  Democrat    Democrat     Democrat      $7.25      $0.70
# 72  2010    Democrat  Democrat    Democrat     Democrat      $7.25      $0.00
# 73  2011    Democrat  Democrat  Republican         None      $7.25      $0.00
#
# ...

# %%
pc_df['Year'] = pc_df['Year'].astype(int)

pc_df = pc_df[(pc_df['Year'] >= 2013) & (pc_df['Year'] <= 2023)]

pc_df.reset_index(drop=True, inplace=True)
pc_df.head(-10)
# Out:
# Empty DataFrame
# Columns: [Year, PresParty, SenParty, HouseParty, TrifectaFlag, FedMinWage, RateChange, PercentChange, IncreaseFlag, YearsSinceLastChange]
# Index: []
